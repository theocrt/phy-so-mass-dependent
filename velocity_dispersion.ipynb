# %%
import numpy as np
import pylab as plt
import pandas as pd
import torch
import physo
import physo.learn.monitoring as monitoring
from data import load_data
import matplotlib.colors as mcolors
import matplotlib.cm as cm

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
models=['1.5M_A_R4_10',
'500k_A_R2_10',
'500k_A_R4_10',
'500k_C_R4_10',
'250k_A_R2_25',
'250k_A_R2_25_vlk',
'250k_A_R2_10',
'250k_A_R2_5',
'250k_A_R4_25',
'250k_A_R4_25_imf50',
'250k_A_R4_25_lk',
'250k_A_R4_25_retr',
'250k_A_R4_25_vlk',
'250k_A_R4_10',
'250k_A_R4_10_retr',
'250k_B_R4_25',
'250k_B_R4_25_lk',
'250k_C_R2_10',
'250k_C_R4_25',
'250k_C_R4_25_lk',
'250k_C_R4_10',
'250k_W6_R4_25',
'250k_W6_R4_25_retr',
'500k_A_R4_LC_part1',
'500k_A_R4_LC_part2']

base_path = f"/pbs/throng/training/astroinfo2025/data/Nbody/"

# %% [markdown]
# # Single model using SR

# %%
# loading model
model1 = load_data.mass_dependent(model_name ='1.5M_A_R4_10',base_path = base_path)
s_phi_ds = load_data.remove_nan(model1, var_name= "s_phi_m",remove_massive=True)

# %%
# 
t = -1 # Each index correspond to an age
plt.figure()
plt.plot(s_phi_ds["m"][t].flatten(),s_phi_ds["s_phi_m"][t],'.',label=f'Age: {s_phi_ds["age"][t]}') # need to flatten according to m. Better for PhySo later
plt.ylabel(r"$\sigma_\phi$[km/s]")
plt.xlabel(r"$M[M_\odot]$")
plt.legend()
plt.show()

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = lambda : monitoring.RunLogger(save_path = save_path_log,
                                                do_save = True)

run_visualiser = lambda : monitoring.RunVisualiser (epoch_refresh_rate = 1,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

# Running SR task
expression, logs = physo.SR(s_phi_ds["m"][-1],s_phi_ds["s_phi_m"][-1],
                            # Giving names of variables (for display purposes)
                            X_names = [ "m"],
                            # Associated physical units (ignore or pass zeroes if irrelevant)
                            X_units = [ [0, 0, 1 ]],
                            # Giving name of root variable (for display purposes)
                            y_name  = "s_phi",
                            y_units = [1, -1, 0],
                            # Fixed constants
                            fixed_consts       = [ 1],
                            fixed_consts_units = [ [0,0,0] ],
                            # Free constants names (for display purposes)
                            free_consts_names = [ "m0"   , "v0"  ],
                            free_consts_units = [ [0, 0, 1] , [1,-1,0] ],
                            # Symbolic operations that can be used to make f
                            op_names = ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "neg", "exp", "log"],
                            get_run_logger     = run_logger,
                            get_run_visualiser = run_visualiser,
                            # Run config
                            run_config = physo.config.config1.config1,
                            # Parallel mode (only available when running from python scripts, not notebooks)
                            parallel_mode = False,
                            # Number of iterations
                            epochs = 10
)
# Out:
# Parallel mode is not available because physo is being ran from a notebook using 'spawn' multiprocessing start method (multiprocessing.get_start_method() = 'spawn'). Run physo from a python script to use parallel mode.
# SR task started...
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/batch_execute.py:80: UserWarning: Parallel mode is not available because physo is being ran from a notebook using 'spawn' multiprocessing start method (multiprocessing.get_start_method() = 'spawn'). Run physo from a python script to use parallel mode.
#   warnings.warn(msg)
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00000 ===========
# -> Time 8.75 s
# -> Memory Usage: 3291.89 MB
#
# Overall best  at R=0.770281
# -> Raw expression :
#            ⎛ 0.5⎞
#            ⎝1   ⎠
#        v₀⋅ℯ
# ────────────────────────
#                      0.5
# ⎛ ⎛             0.5⎞⎞
# ⎜ ⎜⎛        0.5⎞   ⎟⎟
# ⎜ ⎜⎜⎛m + m₀⎞   ⎟   ⎟⎟
# ⎜ ⎜⎜⎜──────⎟   ⎟   ⎟⎟
# ⎜ ⎝⎝⎝  m₀  ⎠   ⎠   ⎠⎟
# ⎝ℯ                  ⎠
#
# Best of epoch at R=0.770281
# -> Raw expression :
#            ⎛ 0.5⎞
#            ⎝1   ⎠
#        v₀⋅ℯ
# ────────────────────────
#                      0.5
# ⎛ ⎛             0.5⎞⎞
# ⎜ ⎜⎛        0.5⎞   ⎟⎟
# ⎜ ⎜⎜⎛m + m₀⎞   ⎟   ⎟⎟
# ⎜ ⎜⎜⎜──────⎟   ⎟   ⎟⎟
# ⎜ ⎝⎝⎝  m₀  ⎠   ⎠   ⎠⎟
# ⎝ℯ                  ⎠
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00001 ===========
# -> Time 62.70 s
# -> Memory Usage: 4596.90 MB
#
# Overall best  at R=0.777820
# -> Raw expression :
#           v₀
# ──────────────────────
#    ⎛      1          ⎞
#    ⎜ ────────────    ⎟
#    ⎜        ⎛-1 ⎞    ⎟
#    ⎜        ⎜───⎟    ⎟
#    ⎜   m    ⎝ 1 ⎠    ⎟
#    ⎜ - ── + ─────    ⎟
#    ⎜   m₀     1      ⎟
# log⎝ℯ             + 1⎠
#
# Best of epoch at R=0.777820
# -> Raw expression :
#           v₀
# ──────────────────────
#    ⎛      1          ⎞
#    ⎜ ────────────    ⎟
#    ⎜        ⎛-1 ⎞    ⎟
#    ⎜        ⎜───⎟    ⎟
#    ⎜   m    ⎝ 1 ⎠    ⎟
#    ⎜ - ── + ─────    ⎟
#    ⎜   m₀     1      ⎟
# log⎝ℯ             + 1⎠
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00002 ===========
# -> Time 58.80 s
# -> Memory Usage: 4612.52 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# Unable to save pareto figure, error:
# Invalid comparison of non-real 1/(-log(1/1))
# =========== Epoch 00003 ===========
# -> Time 62.18 s
# -> Memory Usage: 5055.41 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.788780
# Unable to print status, error:
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# Unable to save pareto figure, error:
# Invalid comparison of non-real 1/(-log(1/1))
# =========== Epoch 00004 ===========
# -> Time 68.74 s
# -> Memory Usage: 5077.16 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.783664
# -> Raw expression :
#            1
# ───────────────────────
# ⎛                  0.5⎞
# ⎜⎛          1     ⎞   ⎟
# ⎜⎜ 1 + ───────────⎟   ⎟
# ⎜⎜     ⎛    m₀⋅v₀⎞⎟   ⎟
# ⎜⎜     ⎜m + ─────⎟⎟   ⎟
# ⎜⎜     ⎜     v₀  ⎟⎟   ⎟
# ⎜⎜     ⎜─────────⎟⎟   ⎟
# ⎜⎜     ⎝    m    ⎠⎟   ⎟
# ⎜⎝ℯ               ⎠   ⎟
# ⎜─────────────────────⎟
# ⎝         v₀          ⎠
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# Unable to save pareto figure, error:
# Invalid comparison of non-real 1/(-log(1/1))
# =========== Epoch 00005 ===========
# -> Time 68.27 s
# -> Memory Usage: 5283.18 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.785244
# -> Raw expression :
#              ⎛ ⎛-m ⎞    ⎞
#              ⎜ ⎜───⎟    ⎟
#              ⎜ ⎝m₀ ⎠    ⎟
#              ⎜ ─────    ⎟
#              ⎜   1      ⎟
#   m⋅v₀⋅v₀⋅log⎝ℯ      + 1⎠
# - ─────────────────────── + v₀
#            m₀⋅v₀
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00006 ===========
# -> Time 77.12 s
# -> Memory Usage: 5243.71 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.791661
# -> Raw expression :
#        ⎛         1          ⎞
#     log⎜────────────────────⎟
#        ⎜        2           ⎟
#        ⎜⎛  m   ⎞     0.5    ⎟
#        ⎜⎜──────⎟  + 1    + 1⎟
#        ⎝⎝m + m₀⎠            ⎠
#     ─────────────────────────
#                 1
# v₀⋅ℯ
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00007 ===========
# -> Time 75.13 s
# -> Memory Usage: 5510.68 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.795826
# -> Raw expression :
#               1
# v₀ + ────────────────────
#      ⎛        m₀        ⎞
#      ⎜──────────────────⎟
#      ⎜⎛       m        ⎞⎟
#      ⎜⎜────────────────⎟⎟
#      ⎜⎜⎛  m           ⎞⎟⎟
#      ⎜⎜⎜  ── + log(1) ⎟⎟⎟
#      ⎜⎜⎜  m₀          ⎟⎟⎟
#      ⎜⎜⎜-ℯ            ⎟⎟⎟
#      ⎜⎜⎜──────────────⎟⎟⎟
#      ⎝⎝⎝      v₀      ⎠⎠⎠
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00008 ===========
# -> Time 75.73 s
# -> Memory Usage: 5501.82 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.796005
# -> Raw expression :
#         v₀
# -v₀ - ───────
#        m
#        ──
#        m₀
#       ℯ   + 1
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00009 ===========
# -> Time 80.38 s
# -> Memory Usage: 5416.85 MB
#
# Overall best  at R=0.796658
# -> Raw expression :
#                    1
# v₀ + 1⋅─────────────────────────
#        ⎛    ⎛   m     ⎞        ⎞
#        ⎜    ⎜   ──    ⎟        ⎟
#        ⎜   2⎜   m₀    ⎟        ⎟
#        ⎜log ⎝- ℯ   - 1⎠ + 1 + 1⎟
#        ⎜───────────────────────⎟
#        ⎝          v₀           ⎠
#
# Best of epoch at R=0.796005
# -> Raw expression :
#              m⋅v₀
# v₀ + ─────────────────────
#        ⎛ m               ⎞
#        ⎜ ──              ⎟
#        ⎜ m₀      ⎛m₀⎞    ⎟
#      m⋅⎜ℯ   + log⎜──⎟ + 1⎟
#        ⎝         ⎝m₀⎠    ⎠

# %% [markdown]
# # Class SR for a single simulation using multiple time steps

# %%
s_phi_multiple = load_data.select_multiple_timesteps(s_phi_ds,n=3,q=5)

# %%
t_values = np.array(s_phi_multiple["age"])
norm = mcolors.Normalize(vmin=np.min(t_values), vmax=np.max(t_values))
cmap = cm.viridis

fig, ax = plt.subplots()
ax.set_xlabel(r"$M [M_\odot]$")
ax.set_ylabel(r"$\sigma_\phi [km/s]$")

for i, t in enumerate(t_values):

    color = cmap(norm(t))
    ax.scatter(s_phi_multiple['m'][i].flatten(), s_phi_multiple['s_phi_m'][i], marker='.', color=color)
    

# Add colorbar linked to this figure and axes
sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('time')
plt.show()

# %%
save_path_training_curves = 'demo_curves.png'
save_path_log             = 'demo.log'

run_logger     = lambda : monitoring.RunLogger(save_path = save_path_log,
                                                do_save = True)

run_visualiser = lambda : monitoring.RunVisualiser (epoch_refresh_rate = 1,
                                           save_path = save_path_training_curves,
                                           do_show   = False,
                                           do_prints = True,
                                           do_save   = True, )

expression, logs = physo.ClassSR(s_phi_multiple["m"], s_phi_multiple["s_phi_m"],
                            # Giving names of variables (for display purposes)
                            X_names = [ "m" ],
                            # Associated physical units (ignore or pass zeroes if irrelevant)
                            X_units = [ [0, 0, 1]],
                            # Giving name of root variable (for display purposes)
                            y_name  = "s_phi",
                            y_units = [1, -1, 0],
                            # Fixed constants
                            fixed_consts       = [ 1.      ],
                            fixed_consts_units = [ [0, 0, 0] ],
                            # Whole class free constants
                            class_free_consts_names = [ "c0"      ,],
                            class_free_consts_units = [ [0, 0, 0] ,],
                            # Realization specific free constants
                            spe_free_consts_names = [ "s0"      , "m0"   , "t0"     ],
                            spe_free_consts_units = [ [1, -1, 0] , [0, 0, 1] , [0, 1, 0]  ],
                            # Run config
                            run_config = physo.config.config1b.config1b,
                            # Symbolic operations that can be used to make f
                            op_names = ["mul", "add", "sub", "div", "inv", "n2", "sqrt", "neg", "exp", "log"],
                            get_run_logger     = run_logger,
                            get_run_visualiser = run_visualiser,
                            # Parallel mode (only available when running from python scripts, not notebooks)
                            parallel_mode = False,
                            # Number of iterations
                            epochs = 2,
)
# Out:
# Parallel mode is not available because physo is being ran from a notebook using 'spawn' multiprocessing start method (multiprocessing.get_start_method() = 'spawn'). Run physo from a python script to use parallel mode.
# SR task started...
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/batch_execute.py:80: UserWarning: Parallel mode is not available because physo is being ran from a notebook using 'spawn' multiprocessing start method (multiprocessing.get_start_method() = 'spawn'). Run physo from a python script to use parallel mode.
#   warnings.warn(msg)
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00000 ===========
# -> Time 15.25 s
# -> Memory Usage: 5134.43 MB
#
# Overall best  at R=0.885894
# -> Raw expression :
#      ⎛                 2⎞
#      ⎜⎛              2⎞ ⎟
#      ⎜⎜⎛      m - m₀⎞ ⎟ ⎟
#      ⎜⎜⎜-c₀ + ──────⎟ ⎟ ⎟
#      ⎝⎝⎝        m₀  ⎠ ⎠ ⎠
# s₀⋅-ℯ                     - s₀
#
# Best of epoch at R=0.885894
# -> Raw expression :
#      ⎛                 2⎞
#      ⎜⎛              2⎞ ⎟
#      ⎜⎜⎛      m - m₀⎞ ⎟ ⎟
#      ⎜⎜⎜-c₀ + ──────⎟ ⎟ ⎟
#      ⎝⎝⎝        m₀  ⎠ ⎠ ⎠
# s₀⋅-ℯ                     - s₀
# /pbs/home/a/astropart22/.local/lib/python3.11/site-packages/physo/physym/prior.py:557: UserWarning: No trigonometric functions detected, (NestedTrigonometryPrior (tokens = [], nesting forbidden)), this prior will be ignored.
#   warnings.warn("No trigonometric functions detected, (%s), this prior will be ignored." % (self))
# =========== Epoch 00001 ===========
# -> Time 235.34 s
# -> Memory Usage: 5349.61 MB
#
# Overall best  at R=0.885894
# -> Raw expression :
#      ⎛                 2⎞
#      ⎜⎛              2⎞ ⎟
#      ⎜⎜⎛      m - m₀⎞ ⎟ ⎟
#      ⎜⎜⎜-c₀ + ──────⎟ ⎟ ⎟
#      ⎝⎝⎝        m₀  ⎠ ⎠ ⎠
# s₀⋅-ℯ                     - s₀
#
# Best of epoch at R=0.885891
# -> Raw expression :
#          m₀⋅s₀
# ───────────────────────
#                 0.5
#       ⎛   1    ⎞
# - c₀⋅-⎜────────⎟    + m
#       ⎜⎛  c₀  ⎞⎟
#       ⎜⎜──────⎟⎟
#       ⎜⎜     2⎟⎟
#       ⎝⎝c₀⋅m₀ ⎠⎠

# %%
best_expr = expression
print(best_expr.get_infix_pretty())
# Out:
#      ⎛                 2⎞
#      ⎜⎛              2⎞ ⎟
#      ⎜⎜⎛      m - m₀⎞ ⎟ ⎟
#      ⎜⎜⎜-c₀ + ──────⎟ ⎟ ⎟
#      ⎝⎝⎝        m₀  ⎠ ⎠ ⎠
# s₀⋅-ℯ                     - s₀
